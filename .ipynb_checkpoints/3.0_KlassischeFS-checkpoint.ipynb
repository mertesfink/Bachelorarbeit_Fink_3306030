# %%
import src.database
from src.Dataset import Dataset
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import src.plot
from src import featureselection

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import xgboost as xgb

# %% [markdown]
# # 1. Univariate Feature Selection (Korrelationskoeffizient)

# %% [markdown]
# ## Optimaler Threshold

# %% [markdown]
# ### Lineare Korrelationszusammenhänge (Heatmap)

# %%
#Vorverarbeitete Daten aus CSV auslesen
df = pd.read_csv("data/df_preprocessed_all.csv", sep = ",")

#Das Label nennen
label = df.columns.get_loc('FELT_LIFE_NET')

N = 10
correlations = df.corrwith(df['FELT_LIFE_NET'], method='pearson')
correlation_df = pd.DataFrame({'Correlation': correlations})
correlation_df = correlation_df.abs().sort_values(by='Correlation', ascending=False)
top_features = correlation_df.index[:N]
# Erstelle eine Heatmap der korrelierten Features
plt.figure(figsize=(10, 8))
sns.heatmap(df[top_features].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap der Korrelationen zwischen den Top {} Features und {}'.format(N, "FELT_LIFE_NET"))
plt.show()

# %% [markdown]
# ### Threshold bestimmen

# %%
#Vorverarbeitete Daten aus CSV auslesen
df = pd.read_csv("data/df_preprocessed_all.csv", sep = ",")

#Das Label nennen
label = df.columns.get_loc('FELT_LIFE_NET')
header = df.columns

#Machine Learning Algorithms die benutzt werden
MLA = [
    ('Linear Regressor',LinearRegression()),
    ('SVR', SVR(kernel='linear')),
    ('Random Forest',RandomForestRegressor()),
    ('Gradient Boosting', xgb.XGBRegressor())
]

results = {}
selected_features = {}

# Farben für die Modelle definieren
colors = ['blue', 'green', 'red', 'black']

plt.figure(figsize=(10, 8))
plt.ylim(20, 85) #Y-Limit setzen, da Linearer Regressor und SVR anfangs sehr hohe Metrikwerte haben

for idx, (model_name, model_instance) in enumerate(MLA):
    
    
    threshold_values = []
    test_rmse_values = []
    test_mae_values = []
    num_features_values = []
    
    threshold = 0.0
    best_threshold_rmse = None
    best_threshold_mae = None
    min_rmse = float('inf')
    min_mae = float('inf')
    best_num_features_rmse = None
    best_num_features_mae = None
    
    
    while threshold <= 1:
        
        #Features für jeden Threshold berechnen und die dazugehörigen Metriken berechnen
        
        dataset = Dataset(df, 'df', label, divide_dataset=False, header=header)
        dataset.divide_dataset(model_instance, all_features=True, all_instances=True, evaluate=False, folds=5)

        selected_feature_names, num_selected_features, duration = featureselection.correlation(dataset.get_X_train(), dataset.get_y_train(), threshold=threshold)
        dataset.set_features(selected_feature_names)
        
        if(len(selected_feature_names)!=0):
           
            if(model_name =="Linear Regressor"):
                selected_features[threshold] = df.columns[selected_feature_names].tolist()

            dataset.fit_classifier()

            dataset.set_test_metrics()
            test = dataset.get_test_metrics()

            threshold_values.append(threshold)
            test_rmse_values.append(test['TestRMSE'])
            test_mae_values.append(test['TestMAE'])
            num_features_values.append(num_selected_features)

            # Überprüfe, ob aktueller Threshold der beste für RMSE ist
            if test['TestRMSE'] < min_rmse:
                min_rmse = test['TestRMSE']
                best_threshold_rmse = threshold
                best_num_features_rmse = num_selected_features

            # Überprüfe, ob aktueller Threshold der beste für MAE ist
            if test['TestMAE'] < min_mae:
                min_mae = test['TestMAE']
                best_threshold_mae = threshold
                best_num_features_mae = num_selected_features
           
            threshold += 0.01
           
        else:
            threshold = 2
        

    results[model_name] = {
        'Threshold': threshold_values,
        'TestRMSE': test_rmse_values,
        'TestMAE': test_mae_values,
        'Feature-Anzahl': num_features_values
    }
    
    # Plot für RMSE erstellen
    plt.plot(threshold_values, test_rmse_values, label=model_name + ' (Best Threshold RMSE: {:.2f})'.format(best_threshold_rmse), color=colors[idx])

    # Plot für MAE erstellen
    plt.plot(threshold_values, test_mae_values, linestyle='--', label=model_name + ' (Best Threshold MAE: {:.2f})'.format(best_threshold_mae), color=colors[idx])
    
    # Vertikale rote Linien hinzufügen, wenn sich die Feature-Anzahl ändert
    prev_num_features = None
    for i, num_features in enumerate(num_features_values):
        if prev_num_features is not None and num_features != prev_num_features:
            plt.axvline(x=threshold_values[i], color='grey', linestyle='-', linewidth=0.4)
            plt.text(threshold_values[i], plt.gca().get_ylim()[1] / 2, str(num_features), rotation=90, verticalalignment='center', horizontalalignment='right', fontsize=8)
        prev_num_features = num_features
    

plt.xlabel('Threshold')
plt.ylabel('Test Score')
plt.title('Test Score für verschiedene Modelle bei unterschiedlichen Threshold-Werten')
plt.legend(loc='upper right',prop={'size': 6}) # Legende in der oberen rechten Ecke

plt.grid(True)
plt.show()

# %% [markdown]
# ## Vorhersage mit bestem Threshold

# %% [markdown]
# ### Code

# %%
#Vorverarbeitete Daten aus CSV auslesen
df = pd.read_csv("data/df_preprocessed_all.csv", sep = ",")

#Das Label nennen
label = df.columns.get_loc('FELT_LIFE_NET')
header = df.columns

#Machine Learning Algorithms die benutzt werden
MLA = [
    ('Linear Regressor',LinearRegression()),
    ('SVR', SVR(kernel='linear')),
    ('Random Forest',RandomForestRegressor()),
    ('Gradient Boosting', xgb.XGBRegressor())
]

results_corr = {}
predictions_corr = {}


# Für alle Modelle in MLA FS mit Korrelationskeoffizienten mit anschließender Validierung
for model_name, model_instance in MLA:
    
    dataset = Dataset(df, 'df', label, divide_dataset=False, header=header)
    dataset.divide_dataset(model_instance, ,normalize=False, all_features=True, all_instances=True, evaluate=False, folds=5)
    
    #FS mit Korrelationskoeffizient
    selected_features, num_selected_features, duration = featureselection.correlation(dataset.get_X_train(), dataset.get_y_train(), threshold=0.03)
    dataset.set_features(selected_features)
    
    #Regressor trainieren
    dataset.fit_classifier()
    
    # Cross-Validation
    dataset.set_CV()
    cv = dataset.get_CV()
    
    #Validierung auf Validation- und Testset
    dataset.set_train_metrics()
    train = dataset.get_train_metrics()
    traintime = dataset.get_traintime()
    
    dataset.set_validation_metrics()
    validation = dataset.get_validation_metrics()
    
    dataset.set_test_metrics()
    test = dataset.get_test_metrics()
    
    
    
    #dataset.plot_shapley_values("FS_corr_"+model_name)
    
    results_corr[model_name] = {
        'Model_name': model_name,
        'CV_TrainMAE': cv['CV_TrainMAE'],
        'CV_TrainRMSE': cv['CV_TrainRMSE'],
        'CV_TestMAE': cv['CV_TestMAE'],
        'CV_TestRMSE': cv['CV_TestRMSE'],
        'CV_fit_time': cv['CV_fit_time'],
        'CV_fit_time_ges':cv['CV_fit_time']+duration,
        'TrainRMSE': train['TrainRMSE'],
        'TrainMAE': train['TrainMAE'],
        'ValidationRMSE': validation['ValidationRMSE'],
        'ValidationMAE': validation['ValidationMAE'],
        'TestRMSE': test['TestRMSE'],
        'TestMAE': test['TestMAE'],
        'TrainTime': traintime,
        'TrainTime_ges': traintime+duration,
        'Features': selected_features,
        'Feature-Anzahl': num_selected_features,
        'FS-Laufzeit': duration
    }
    
    predictions_corr[model_name] = {
    'Model_name': model_name,
    'y_train': dataset.get_y_train(),
    'y_val': dataset.get_y_val(),
    'y_test': dataset.get_y_test(),
    'pred_train': dataset.get_y_pred_train(),
    'pred_val': dataset.get_y_pred_val(),
    'pred_test':dataset.get_y_pred_test()
    }
    print(model_name)
# Out:
# Linear Regressor
# SVR
# Random Forest
# Gradient Boosting

# %% [markdown]
# ### Speichern der Ergebnisse (Corr)

# %%
#Metriken speichern
df_corr = pd.DataFrame(results_corr.copy())
df_corr = df_corr.transpose()
df_corr.to_csv('data/Corr/All_FS_corr_metrics.csv', index=False)

#Ausgewählten Features für die einzelnen Algorithmen speichern 
df_features_corr = pd.DataFrame()
# Iteration über die Modelle und Hinzufügen der Feature-Namen in df_features_corr
for model_name, model_instance in MLA:
    selected_features = df.columns[results_corr[model_name]['Features']].tolist()
    
    # Die ausgewählten Spaltennamen in eine neue Spalte in df_features_corr einfügen
    df_features_corr[model_name] = selected_features

df_features_corr.to_csv('data/Corr/All_FS_corr_Features.csv', index=False)


#Predictions speichern
corr_data = []
# Iteriere über die Modelle und ihre Daten
for model_name, data in predictions_corr.items():
    model_data = data.copy()
    model_data.pop('Model_name')  # Entferne den Eintrag 'Model_name'
    for data_type, values in model_data.items():
        # Iteriere über die Werte in jedem Datenfeld und füge sie zur flattened_data-Liste hinzu
        for value in values:
            corr_data.append({'Model_name': model_name, 'Data_type': data_type, 'Value': value})


df = pd.DataFrame(corr_data)
df.to_csv('data/Corr/All_FS_corr_predictions.csv', index=False)

# %% [markdown]
# # 2. Rekursive Feature Elimination (RFE)

# %% [markdown]
# ## Grafik RFE Evaluationsproblem

# %%
#Vorverarbeitete Daten aus CSV auslesen
df = pd.read_csv("data/df_preprocessed_all.csv", sep = ",")
print(df.shape)
#Das Label nennen
label = df.columns.get_loc('FELT_LIFE_NET')
header = df.columns

#Machine Learning Algorithms die benutzt werden
MLA = [
    ('Linear Regressor',LinearRegression()),
    #('SVR', SVR(kernel='linear')),
    #('Random Forest',RandomForestRegressor()),
    #('Gradient Boosting', xgb.XGBRegressor())
]


# Für alle Modelle in MLA FS mit Korrelationskeoffizienten mit anschließender Validierung
for model_name, model_instance in MLA:
    
    dataset = Dataset(df, 'df', label, divide_dataset=False, header=header)
    dataset.divide_dataset(model_instance, all_features=True, all_instances=True, evaluate=False, folds=5)
    
    X = dataset.get_X_train()
    y = dataset.get_y_train()
    max_features = 200
    featureselection. visualize_rfe_runtime(model_instance, X, y, max_features, step=20, time_limit=1000)
# Out:
# (8796, 473)
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In [2], line 26
#      24 y = dataset.get_y_train()
#      25 max_features = 200
# ---> 26 featureselection. visualize_rfe_runtime(model_instance, X, y, max_features, step=20, time_limit=1000)
#
# File ~/work/praxisprojekt/src/featureselection.py:96, in visualize_rfe_runtime(model, X, y, max_features, step, time_limit)
#      94 rfe = RFE(estimator=model, n_features_to_select=n_features_to_select, step=20)
#      95 # Führe RFE auf den Daten durch
# ---> 96 rfe.fit(X, y)
#      98 # Endzeit der aktuellen Iteration
#      99 iteration_end_time = time.time()
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/base.py:1466, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1461 partial_fit_and_fitted = (
#    1462     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1463 )
#    1465 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
#    1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/base.py:666, in BaseEstimator._validate_params(self)
#     658 def _validate_params(self):
#     659     """Validate types and values of constructor parameters
#     660
#     661     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     664     accepted constraints.
#     665     """
# --> 666     validate_parameter_constraints(
#     667         self._parameter_constraints,
#     668         self.get_params(deep=False),
#     669         caller_name=self.__class__.__name__,
#     670     )
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'n_features_to_select' parameter of RFE must be None, a float in the range (0.0, 1.0] or an int in the range (0, inf). Got 0 instead.

# %% [markdown]
# ## Einzelner Evaluationsschritt

# %% [markdown]
# ### Code

# %%
#Vorverarbeitete Daten aus CSV auslesen
df = pd.read_csv("data/df_preprocessed_all.csv", sep = ",")

#Das Label nennen
label = df.columns.get_loc('FELT_LIFE_NET')
header = df.columns

#Machine Learning Algorithms die benutzt werden
MLA = [
    ('Linear Regressor',LinearRegression()),
    ('SVR', SVR(kernel='linear')),
    ('Random Forest',RandomForestRegressor()),
    ('Gradient Boosting', xgb.XGBRegressor())
]

results_rfe = {}
predictions_rfe = {}

# Für alle Modelle in MLA FS mit Korrelationskeoffizienten mit anschließender Validierung
for model_name, model_instance in MLA:
    
    dataset = Dataset(df, 'df', label, divide_dataset=False, header=header) 
    dataset.divide_dataset(model_instance, all_features=True, all_instances=True, evaluate=False, folds=5)
    
    #FS mit RFE
    selected_features, num_selected_features, duration = featureselection.rfe(model_instance, dataset.get_X_train(), dataset.get_y_train(), n_features_to_select=300, step=1)
    dataset.set_features(selected_features)
    
    #Regressor trainieren
    dataset.fit_regressor()
    
    # Cross-Validation
    dataset.set_CV()
    cv = dataset.get_CV()
    
    #Validierung auf Validation- und Testset
    dataset.set_train_metrics()
    train = dataset.get_train_metrics()
    traintime = dataset.get_traintime()
    
    dataset.set_validation_metrics()
    validation = dataset.get_validation_metrics()
    
    dataset.set_test_metrics()
    test = dataset.get_test_metrics()
    
    #dataset.plot_shapley_values("FS_corr_"+model_name)
    
    results_rfe[model_name] = {
        'Model_name': model_name,
        'CV_TrainMAE': cv['CV_TrainMAE'],
        'CV_TrainRMSE': cv['CV_TrainRMSE'],
        'CV_TestMAE': cv['CV_TestMAE'],
        'CV_TestRMSE': cv['CV_TestRMSE'],
        'CV_fit_time': cv['CV_fit_time'],
        'CV_fit_time_ges':cv['CV_fit_time']+duration,
        'TrainRMSE': train['TrainRMSE'],
        'TrainMAE': train['TrainMAE'],
        'ValidationRMSE': validation['ValidationRMSE'],
        'ValidationMAE': validation['ValidationMAE'],
        'TestRMSE': test['TestRMSE'],
        'TestMAE': test['TestMAE'],
        'TrainTime': traintime,
        'TrainTime_ges': traintime+duration,
        'Features': selected_features,
        'Feature-Anzahl': num_selected_features,
        'FS-Laufzeit': duration
    }
    
    predictions_rfe[model_name] = {
    'Model_name': model_name,
    'y_train': dataset.get_y_train(),
    'y_val': dataset.get_y_val(),
    'y_test': dataset.get_y_test(),
    'pred_train': dataset.get_y_pred_train(),
    'pred_val': dataset.get_y_pred_val(),
    'pred_test':dataset.get_y_pred_test()
    }

# %%
for item in evaluation:
    for model_name, model_instance in MLA:
        plot.residuen_histo(predictions_rfe[model_name], evaluation=item, name="All_FS_rfe", range_min=None, range_max=None)

# %%
for item in evaluation:
    plot.model_results_barplot(results_rfe, metrics_upper_limit=None, runtime_upper_limit=None, plot_runtime=True, evaluation=item,name="All_FS_rfe", FS=True)

# %% [markdown]
# ### Speichern der Ergebnisse (RFE)

# %%
df_rfe = pd.DataFrame(results_rfe)
df_rfe = df_rfe.transpose()
df_rfe.to_csv('data/RFE/All_FS_rfe_metrics.csv', index=False)

# Features der RFE speichern
df_features_rfe = pd.DataFrame()
# Iteration über die Modelle und Hinzufügen der Feature-Namen in df_features_rfe
for model_name, model_instance in MLA:
    selected_features = df.columns[results_rfe[model_name]['Features']].tolist()
    
    # Die ausgewählten Spaltennamen in eine neue Spalte in df_features_rfe einfügen
    df_features_rfe[model_name] = selected_features

df_features_rfe.to_csv('data/RFE/All_FS_rfe_Features.csv', index=False)

#Predictions speichern
rfe_data = []
# Iteriere über die Modelle und ihre Daten
for model_name, data in predictions_rfe.items():
    model_data = data.copy()
    model_data.pop('Model_name')  # Entferne den Eintrag 'Model_name'
    for data_type, values in model_data.items():
        # Iteriere über die Werte in jedem Datenfeld und füge sie zur flattened_data-Liste hinzu
        for value in values:
            rfe_data.append({'Model_name': model_name, 'Data_type': data_type, 'Value': value})


df = pd.DataFrame(rfe_data)
df.to_csv('data/RFE/All_FS_rfe_predictions.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [11], line 9
#       7 # Iteration über die Modelle und Hinzufügen der Feature-Namen in df_features_rfe
#       8 for model_name, model_instance in MLA:
# ----> 9     selected_features = df.columns[results_rfe[model_name]['Features']].tolist()
#      11     # Die ausgewählten Spaltennamen in eine neue Spalte in df_features_rfe einfügen
#      12     df_features_rfe[model_name] = selected_features
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:5377, in Index.__getitem__(self, key)
#    5374     else:
#    5375         key = np.asarray(key, dtype=bool)
# -> 5377 result = getitem(key)
#    5378 # Because we ruled out integer above, we always get an arraylike here
#    5379 if result.ndim > 1:
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 315 but corresponding boolean dimension is 314
